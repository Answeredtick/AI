# %% [markdown]
# # Question:
# ***how frequently is a mushrooms observed habitat in meadows***

# %% [markdown]
# This is a observational study because i am reading through the data to gather the info without changing or controlling any of it

# %%
import pandas as pd

# %%
import seaborn

# %%
df = pd.read_csv("mushrooms.csv")

# %%
print(df.head(12))
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      p         x           s         n       t    p               f
# 1      e         x           s         y       t    a               f
# 2      e         b           s         w       t    l               f
# 3      p         x           y         w       t    p               f
# 4      e         x           s         g       f    n               f
# 5      e         x           y         y       t    a               f
# 6      e         b           s         w       t    a               f
# 7      e         b           y         w       t    l               f
# 8      p         x           y         w       t    p               f
# 9      e         b           s         y       t    a               f
# 10     e         x           y         y       t    l               f
# 11     e         x           y         y       t    a               f
#
# ...

# %%
df.head(15)
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      p         x           s         n       t    p               f
# 1      e         x           s         y       t    a               f
# 2      e         b           s         w       t    l               f
# 3      p         x           y         w       t    p               f
# 4      e         x           s         g       f    n               f
# 5      e         x           y         y       t    a               f
# 6      e         b           s         w       t    a               f
# 7      e         b           y         w       t    l               f
# 8      p         x           y         w       t    p               f
# 9      e         b           s         y       t    a               f
# 10     e         x           y         y       t    l               f
# 11     e         x           y         y       t    a               f
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   str
#  1   cap-shape                 8124 non-null   str
#  2   cap-surface               8124 non-null   str
#  3   cap-color                 8124 non-null   str
#  4   bruises                   8124 non-null   str
#  5   odor                      8124 non-null   str
#  6   gill-attachment           8124 non-null   str
#  7   gill-spacing              8124 non-null   str
#  8   gill-size                 8124 non-null   str
#  9   gill-color                8124 non-null   str
#  10  stalk-shape               8124 non-null   str
#  11  stalk-root                8124 non-null   str
#  12  stalk-surface-above-ring  8124 non-null   str
#  13  stalk-surface-below-ring  8124 non-null   str
# ...

# %%
M = (df[df["habitat"] == "m"])

# %%
count= len(M)
print("habitat: ", count)
# Out:
# habitat:  292

# %%
df["habitat"].value_counts()
# Out:
# habitat
# d    3148
# g    2148
# p    1144
# l     832
# u     368
# m     292
# w     192
# Name: count, dtype: int64

# %%
seaborn.countplot(data=df, x="habitat")
# Out:
# <Axes: xlabel='habitat', ylabel='count'>

# %%
seaborn.barplot(df["habitat"])
# Out:
# <Axes: ylabel='habitat'>

# %% [markdown]
# #  Conclusion:
#
# 292 of the mushrooms natural habitat is in the meadows
# ![image.png](attachment:8a5de279-614a-4d83-8f05-1a2348529f64.png)
# while unable to tell the exact number you can tell that less than 300 of the mushrooms in the data grow naturally in the meadows
